# %%
# assuming processed_SEOBNRv4, psd_H1 are already defined as arrays with values corresponding to the frequency bins

import numpy as np
from scipy import integrate
from scipy.interpolate import interp1d

def h_tilde(f, idx, processed_SEOBNRv4):
    waveform_data = processed_SEOBNRv4[idx]  # Waveform data from SEOBNRv4 index
    
    # FT data
    h_tilde_data = np.fft.rfft(waveform_data)
    
    # Interpolate to evaluate at frequency
    h_tilde_interp = interp1d(np.fft.rfftfreq(len(waveform_data), dt), h_tilde_data, bounds_error=False, fill_value=0)
    
    return h_tilde_interp[f]

def psd(f):
    return psd_H1[f]  # Get PSD at frequency f

def optimal_snr_squared(h_tilde, psd, f_min, f_max, idx, f):
    def integrand(f):
        ht = h_tilde(f, idx)
        return np.abs(ht)**2 / psd(f) if psd(f) != 0 else 0

    result, _ = integrate.quad(integrand, f_min, f_max)
    rho_opt_squared = 4 * result

    return rho_opt_squared


for f in range(freqs):
    rho_opt_squared = optimal_snr_squared(h_tilde, psd, f_min, f_max, idx, f)
    print(f'Optimal SNR squared at frequency {f} is {rho_opt_squared}')
