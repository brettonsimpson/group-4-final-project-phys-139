# %% [markdown]
# **Work-in-Progress Convolutional Neural Network Model for Gravitational Wave Signal Classification**

# %%
import numpy as np
import matplotlib.pyplot as plt

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, ReLU, MaxPooling1D, Flatten, Dense, Softmax

import gdown

# %%
data_directory = ''

# %% [markdown]
# **Defining a Function for Generating Convolutional Blocks**

# %%
def convolutional_layer_block(filters, kernel_size, strides=1, pool_size=4, input_shape=None):
    
    block = Sequential()
    
    if input_shape:
        block.add(Conv1D(filters=filters, kernel_size=kernel_size, strides=strides, padding='same', input_shape=input_shape))
    else:
        block.add(Conv1D(filters=filters, kernel_size=kernel_size, strides=strides, padding='same'))
    
    block.add(ReLU())
    block.add(BatchNormalization())
    
    block.add(Conv1D(filters=filters, kernel_size=kernel_size, strides=strides, padding='same'))
    block.add(ReLU())
    block.add(BatchNormalization())
    
    block.add(Conv1D(filters=filters, kernel_size=kernel_size, strides=strides, padding='same'))
    block.add(ReLU())
    block.add(BatchNormalization())
    
    block.add(MaxPooling1D(pool_size=pool_size))
    
    return block

# %% [markdown]
# **Defining a Function for Generating Dense Neuron Blocks**

# %%
def dense_layer_block(neurons, input_shape=None):
    
    block = Sequential()
    
    if input_shape:
        block.add(Dense(neurons, input_shape=input_shape))
    else:
        block.add(Dense(neurons))
        
    block.add(ReLU())
    block.add(BatchNormalization())
    
    return block

# %% [markdown]
# **Defining a Function for Producing a Softmax Output Block**

# %% [markdown]
# **Initializing the Model**

# %%
model = Sequential()

# %% [markdown]
# **First CNN Layer** <br>
# 32 Filter Convolutional Block

# %%
model.add(convolutional_layer_block(filters=32, kernel_size=3))

# %% [markdown]
# **Second CNN Layer** <br>
# 64 Filter Convolutional Block

# %%
model.add(convolutional_layer_block(filters=64, kernel_size=3))

# %% [markdown]
# **Third CNN Layer** <br>
# 128 Filter Convolutional Block

# %%
model.add(convolutional_layer_block(filters=128, kernel_size=3))

# %% [markdown]
# **Fourth CNN Layer** <br>
# 256 Filter Convolutional Block

# %%
model.add(convolutional_layer_block(filters=256, kernel_size=3, pool_size=1))

# %% [markdown]
# **Fifth CNN Layer** <br>
# Flattening Block

# %%
model.add(Flatten())

# %% [markdown]
# **Sixth CNN Layer** <br>
# 128-Neuron Dense Block

# %%
model.add(dense_layer_block(neurons=128))

# %% [markdown]
# **Seventh CNN Layer** <br>
# 164-Neuron Dense Block

# %%
model.add(dense_layer_block(neurons=64))

# %% [markdown]
# **Eighth CNN Layer** <br>
# 4-Neuron Dense Block

# %%
model.add(dense_layer_block(neurons=3))

# %% [markdown]
# **Ninth CNN Layer** <br>
# Softmax Output Block

# %%
model.add(Softmax())

# %% [markdown]
# **Model Compiling Stage**

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(), 
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# %%
def generate_time_series(num_samples, sequence_length):
    X = []
    y = []

    for i in range(num_samples):
        # Randomly select a class
        class_label = np.random.randint(0, 3)
        
        # Generate time series data based on the class
        if class_label == 0:
            # Class 0: Sinusoidal pattern
            time_series = np.sin(np.arange(sequence_length) * np.pi / 10)
        elif class_label == 1:
            # Class 1: Linearly increasing pattern
            time_series = np.arange(sequence_length) / sequence_length
        else:
            # Class 2: Random noise
            time_series = np.random.rand(sequence_length)

        # Append generated data to the lists
        X.append(time_series)
        y.append(class_label)

    return np.array(X), np.array(y)

# %%
# Generate sample time series data
X_train, y_train = generate_time_series(num_samples=10000, sequence_length=100)
X_test, y_test = generate_time_series(num_samples=10000, sequence_length=100)

# Reshape the data to fit the expected input shape of the model
X_train = X_train.reshape(-1, 100, 1)
X_test = X_test.reshape(-1, 100, 1)

# Train the model
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9187 - loss: 0.3770 - val_accuracy: 0.3240 - val_loss: 1.4565
# Epoch 2/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 0.1540 - val_accuracy: 0.3240 - val_loss: 1.5661
# Epoch 3/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 1.0000 - loss: 0.1114 - val_accuracy: 1.0000 - val_loss: 0.1141
# Epoch 4/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 0.0832 - val_accuracy: 1.0000 - val_loss: 0.0426
# Epoch 5/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 0.0651 - val_accuracy: 0.6560 - val_loss: 0.3549
# Epoch 6/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 0.0506 - val_accuracy: 1.0000 - val_loss: 0.0504
# Epoch 7/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 0.0415 - val_accuracy: 1.0000 - val_loss: 0.0280
# Epoch 8/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 0.0355 - val_accuracy: 1.0000 - val_loss: 0.0396
# Epoch 9/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 0.0290 - val_accuracy: 1.0000 - val_loss: 0.0119
# Epoch 10/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 0.0252 - val_accuracy: 1.0000 - val_loss: 0.0114
# Epoch 11/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 0.0200 - val_accuracy: 1.0000 - val_loss: 0.0112
# Epoch 12/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 0.0173 - val_accuracy: 1.0000 - val_loss: 0.0129
# Epoch 13/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 0.0155 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 14/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 15/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 16/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 17/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 18/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 19/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 20/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0046
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0044
# Test accuracy: 1.0

# %%
import tensorflow as tf

# Get the list of available physical devices (CPUs, GPUs)
devices = tf.config.experimental.list_physical_devices('GPU')

if devices:
    # TensorFlow is using GPU
    print("TensorFlow is using GPU:", devices[0].name)
else:
    # TensorFlow is using CPU
    print("TensorFlow is using CPU")
# Out:
# C:\Users\brett\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\framework\dtypes.py:585: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   np.object,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       3 # Get the list of available physical devices (CPUs, GPUs)
#       4 devices = tf.config.experimental.list_physical_devices('GPU')
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\__init__.py:41
#      38 import six as _six
#      39 import sys as _sys
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      44 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\__init__.py:46
#      41 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
#      43 # pylint: enable=wildcard-import
#      44
#      45 # Bring in subpackages.
# ---> 46 from tensorflow.python import data
#      47 from tensorflow.python import distribute
#      48 # from tensorflow.python import keras
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\data\__init__.py:25
#      22 from __future__ import print_function
#      24 # pylint: disable=unused-import
# ---> 25 from tensorflow.python.data import experimental
#      26 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      27 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\data\experimental\__init__.py:97
#      94 from __future__ import print_function
#      96 # pylint: disable=unused-import
# ---> 97 from tensorflow.python.data.experimental import service
#      98 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#      99 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\data\experimental\service\__init__.py:353
#     350 from __future__ import division
#     351 from __future__ import print_function
# --> 353 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     354 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     355 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\data\experimental\ops\data_service_ops.py:26
#      24 from tensorflow.python import tf2
#      25 from tensorflow.python.compat import compat
# ---> 26 from tensorflow.python.data.experimental.ops import compression_ops
#      27 from tensorflow.python.data.experimental.ops.distribute_options import AutoShardPolicy
#      28 from tensorflow.python.data.experimental.ops.distribute_options import ExternalStatePolicy
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\data\experimental\ops\compression_ops.py:20
#      17 from __future__ import division
#      18 from __future__ import print_function
# ---> 20 from tensorflow.python.data.util import structure
#      21 from tensorflow.python.ops import gen_experimental_dataset_ops as ged_ops
#      24 def compress(element):
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\data\util\structure.py:26
#      23 import six
#      24 import wrapt
# ---> 26 from tensorflow.python.data.util import nest
#      27 from tensorflow.python.framework import composite_tensor
#      28 from tensorflow.python.framework import ops
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\data\util\nest.py:40
#      36 from __future__ import print_function
#      38 import six as _six
# ---> 40 from tensorflow.python.framework import sparse_tensor as _sparse_tensor
#      41 from tensorflow.python.util import _pywrap_utils
#      42 from tensorflow.python.util import nest
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\framework\sparse_tensor.py:28
#      26 from tensorflow.python import tf2
#      27 from tensorflow.python.framework import composite_tensor
# ---> 28 from tensorflow.python.framework import constant_op
#      29 from tensorflow.python.framework import dtypes
#      30 from tensorflow.python.framework import ops
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\framework\constant_op.py:29
#      27 from tensorflow.core.framework import types_pb2
#      28 from tensorflow.python.eager import context
# ---> 29 from tensorflow.python.eager import execute
#      30 from tensorflow.python.framework import dtypes
#      31 from tensorflow.python.framework import op_callbacks
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\eager\execute.py:27
#      25 from tensorflow.python import pywrap_tfe
#      26 from tensorflow.python.eager import core
# ---> 27 from tensorflow.python.framework import dtypes
#      28 from tensorflow.python.framework import ops
#      29 from tensorflow.python.framework import tensor_shape
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\framework\dtypes.py:585
#     556     _NP_TO_TF[pdt] = next(
#     557         _NP_TO_TF[dt] for dt in _NP_TO_TF if dt == pdt().dtype)  # pylint: disable=no-value-for-parameter
#     559 TF_VALUE_DTYPES = set(_NP_TO_TF.values())
#     561 _TF_TO_NP = {
#     562     types_pb2.DT_HALF:
#     563         np.float16,
#     564     types_pb2.DT_FLOAT:
#     565         np.float32,
#     566     types_pb2.DT_DOUBLE:
#     567         np.float64,
#     568     types_pb2.DT_INT32:
#     569         np.int32,
#     570     types_pb2.DT_UINT8:
#     571         np.uint8,
#     572     types_pb2.DT_UINT16:
#     573         np.uint16,
#     574     types_pb2.DT_UINT32:
#     575         np.uint32,
#     576     types_pb2.DT_UINT64:
#     577         np.uint64,
#     578     types_pb2.DT_INT16:
#     579         np.int16,
#     580     types_pb2.DT_INT8:
#     581         np.int8,
#     582     # NOTE(touts): For strings we use np.object as it supports variable length
#     583     # strings.
#     584     types_pb2.DT_STRING:
# --> 585         np.object,
#     586     types_pb2.DT_COMPLEX64:
#     587         np.complex64,
#     588     types_pb2.DT_COMPLEX128:
#     589         np.complex128,
#     590     types_pb2.DT_INT64:
#     591         np.int64,
#     592     types_pb2.DT_BOOL:
#     593         np.bool_,
#     594     types_pb2.DT_QINT8:
#     595         _np_qint8,
#     596     types_pb2.DT_QUINT8:
#     597         _np_quint8,
#     598     types_pb2.DT_QINT16:
#     599         _np_qint16,
#     600     types_pb2.DT_QUINT16:
#     601         _np_quint16,
#     602     types_pb2.DT_QINT32:
#     603         _np_qint32,
#     604     types_pb2.DT_BFLOAT16:
#     605         _np_bfloat16,
#     606
#     607     # Ref types
#     608     types_pb2.DT_HALF_REF:
#     609         np.float16,
#     610     types_pb2.DT_FLOAT_REF:
#     611         np.float32,
#     612     types_pb2.DT_DOUBLE_REF:
#     613         np.float64,
#     614     types_pb2.DT_INT32_REF:
#     615         np.int32,
#     616     types_pb2.DT_UINT32_REF:
#     617         np.uint32,
#     618     types_pb2.DT_UINT8_REF:
#     619         np.uint8,
#     620     types_pb2.DT_UINT16_REF:
#     621         np.uint16,
#     622     types_pb2.DT_INT16_REF:
#     623         np.int16,
#     624     types_pb2.DT_INT8_REF:
#     625         np.int8,
#     626     types_pb2.DT_STRING_REF:
#     627         np.object,
#     628     types_pb2.DT_COMPLEX64_REF:
#     629         np.complex64,
#     630     types_pb2.DT_COMPLEX128_REF:
#     631         np.complex128,
#     632     types_pb2.DT_INT64_REF:
#     633         np.int64,
#     634     types_pb2.DT_UINT64_REF:
#     635         np.uint64,
#     636     types_pb2.DT_BOOL_REF:
#     637         np.bool,
#     638     types_pb2.DT_QINT8_REF:
#     639         _np_qint8,
#     640     types_pb2.DT_QUINT8_REF:
#     641         _np_quint8,
#     642     types_pb2.DT_QINT16_REF:
#     643         _np_qint16,
#     644     types_pb2.DT_QUINT16_REF:
#     645         _np_quint16,
#     646     types_pb2.DT_QINT32_REF:
#     647         _np_qint32,
#     648     types_pb2.DT_BFLOAT16_REF:
#     649         _np_bfloat16,
#     650 }
#     652 _QUANTIZED_DTYPES_NO_REF = frozenset([qint8, quint8, qint16, quint16, qint32])
#     653 _QUANTIZED_DTYPES_REF = frozenset(
#     654     [qint8_ref, quint8_ref, qint16_ref, quint16_ref, qint32_ref])
#
# File ~\anaconda3\envs\tflow\lib\site-packages\numpy\__init__.py:305, in __getattr__(attr)
#     300     warnings.warn(
#     301         f"In the future `np.{attr}` will be defined as the "
#     302         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     304 if attr in __former_attrs__:
# --> 305     raise AttributeError(__former_attrs__[attr])
#     307 # Importing Tester requires importing all of UnitTest which is not a
#     308 # cheap import Since it is mainly used in test suits, we lazy import it
#     309 # here to save on the order of 10 ms of import time for most users
#     310 #
#     311 # The previous way Tester was imported also had a side effect of adding
#     312 # the full `numpy.testing` namespace
#     313 if attr == 'testing':
#
# AttributeError: module 'numpy' has no attribute 'object'.
# `np.object` was a deprecated alias for the builtin `object`. To avoid this error in existing code, use `object` by itself. Doing this will not modify any behavior and is safe.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
import os
import tensorflow as tf

# Check available physical devices (CPUs, GPUs)
devices = tf.config.experimental.list_physical_devices('GPU')

if devices:
    for device in devices:
        print("Name:", device.name, "Type:", device.device_type)
    os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Set the GPU index you want to use
    for device in devices:
        tf.config.experimental.set_memory_growth(device, True)
else:
    print("No GPU available")

# Your TensorFlow code here
# Out:
# C:\Users\brett\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\framework\dtypes.py:585: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   np.object,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 import os
# ----> 2 import tensorflow as tf
#       4 # Check available physical devices (CPUs, GPUs)
#       5 devices = tf.config.experimental.list_physical_devices('GPU')
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\__init__.py:41
#      38 import six as _six
#      39 import sys as _sys
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      44 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\__init__.py:46
#      41 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
#      43 # pylint: enable=wildcard-import
#      44
#      45 # Bring in subpackages.
# ---> 46 from tensorflow.python import data
#      47 from tensorflow.python import distribute
#      48 # from tensorflow.python import keras
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\data\__init__.py:25
#      22 from __future__ import print_function
#      24 # pylint: disable=unused-import
# ---> 25 from tensorflow.python.data import experimental
#      26 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      27 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\data\experimental\__init__.py:97
#      94 from __future__ import print_function
#      96 # pylint: disable=unused-import
# ---> 97 from tensorflow.python.data.experimental import service
#      98 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#      99 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\data\experimental\service\__init__.py:353
#     350 from __future__ import division
#     351 from __future__ import print_function
# --> 353 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     354 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     355 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\data\experimental\ops\data_service_ops.py:26
#      24 from tensorflow.python import tf2
#      25 from tensorflow.python.compat import compat
# ---> 26 from tensorflow.python.data.experimental.ops import compression_ops
#      27 from tensorflow.python.data.experimental.ops.distribute_options import AutoShardPolicy
#      28 from tensorflow.python.data.experimental.ops.distribute_options import ExternalStatePolicy
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\data\experimental\ops\compression_ops.py:20
#      17 from __future__ import division
#      18 from __future__ import print_function
# ---> 20 from tensorflow.python.data.util import structure
#      21 from tensorflow.python.ops import gen_experimental_dataset_ops as ged_ops
#      24 def compress(element):
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\data\util\structure.py:26
#      23 import six
#      24 import wrapt
# ---> 26 from tensorflow.python.data.util import nest
#      27 from tensorflow.python.framework import composite_tensor
#      28 from tensorflow.python.framework import ops
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\data\util\nest.py:40
#      36 from __future__ import print_function
#      38 import six as _six
# ---> 40 from tensorflow.python.framework import sparse_tensor as _sparse_tensor
#      41 from tensorflow.python.util import _pywrap_utils
#      42 from tensorflow.python.util import nest
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\framework\sparse_tensor.py:28
#      26 from tensorflow.python import tf2
#      27 from tensorflow.python.framework import composite_tensor
# ---> 28 from tensorflow.python.framework import constant_op
#      29 from tensorflow.python.framework import dtypes
#      30 from tensorflow.python.framework import ops
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\framework\constant_op.py:29
#      27 from tensorflow.core.framework import types_pb2
#      28 from tensorflow.python.eager import context
# ---> 29 from tensorflow.python.eager import execute
#      30 from tensorflow.python.framework import dtypes
#      31 from tensorflow.python.framework import op_callbacks
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\eager\execute.py:27
#      25 from tensorflow.python import pywrap_tfe
#      26 from tensorflow.python.eager import core
# ---> 27 from tensorflow.python.framework import dtypes
#      28 from tensorflow.python.framework import ops
#      29 from tensorflow.python.framework import tensor_shape
#
# File ~\anaconda3\envs\tflow\lib\site-packages\tensorflow\python\framework\dtypes.py:585
#     556     _NP_TO_TF[pdt] = next(
#     557         _NP_TO_TF[dt] for dt in _NP_TO_TF if dt == pdt().dtype)  # pylint: disable=no-value-for-parameter
#     559 TF_VALUE_DTYPES = set(_NP_TO_TF.values())
#     561 _TF_TO_NP = {
#     562     types_pb2.DT_HALF:
#     563         np.float16,
#     564     types_pb2.DT_FLOAT:
#     565         np.float32,
#     566     types_pb2.DT_DOUBLE:
#     567         np.float64,
#     568     types_pb2.DT_INT32:
#     569         np.int32,
#     570     types_pb2.DT_UINT8:
#     571         np.uint8,
#     572     types_pb2.DT_UINT16:
#     573         np.uint16,
#     574     types_pb2.DT_UINT32:
#     575         np.uint32,
#     576     types_pb2.DT_UINT64:
#     577         np.uint64,
#     578     types_pb2.DT_INT16:
#     579         np.int16,
#     580     types_pb2.DT_INT8:
#     581         np.int8,
#     582     # NOTE(touts): For strings we use np.object as it supports variable length
#     583     # strings.
#     584     types_pb2.DT_STRING:
# --> 585         np.object,
#     586     types_pb2.DT_COMPLEX64:
#     587         np.complex64,
#     588     types_pb2.DT_COMPLEX128:
#     589         np.complex128,
#     590     types_pb2.DT_INT64:
#     591         np.int64,
#     592     types_pb2.DT_BOOL:
#     593         np.bool_,
#     594     types_pb2.DT_QINT8:
#     595         _np_qint8,
#     596     types_pb2.DT_QUINT8:
#     597         _np_quint8,
#     598     types_pb2.DT_QINT16:
#     599         _np_qint16,
#     600     types_pb2.DT_QUINT16:
#     601         _np_quint16,
#     602     types_pb2.DT_QINT32:
#     603         _np_qint32,
#     604     types_pb2.DT_BFLOAT16:
#     605         _np_bfloat16,
#     606
#     607     # Ref types
#     608     types_pb2.DT_HALF_REF:
#     609         np.float16,
#     610     types_pb2.DT_FLOAT_REF:
#     611         np.float32,
#     612     types_pb2.DT_DOUBLE_REF:
#     613         np.float64,
#     614     types_pb2.DT_INT32_REF:
#     615         np.int32,
#     616     types_pb2.DT_UINT32_REF:
#     617         np.uint32,
#     618     types_pb2.DT_UINT8_REF:
#     619         np.uint8,
#     620     types_pb2.DT_UINT16_REF:
#     621         np.uint16,
#     622     types_pb2.DT_INT16_REF:
#     623         np.int16,
#     624     types_pb2.DT_INT8_REF:
#     625         np.int8,
#     626     types_pb2.DT_STRING_REF:
#     627         np.object,
#     628     types_pb2.DT_COMPLEX64_REF:
#     629         np.complex64,
#     630     types_pb2.DT_COMPLEX128_REF:
#     631         np.complex128,
#     632     types_pb2.DT_INT64_REF:
#     633         np.int64,
#     634     types_pb2.DT_UINT64_REF:
#     635         np.uint64,
#     636     types_pb2.DT_BOOL_REF:
#     637         np.bool,
#     638     types_pb2.DT_QINT8_REF:
#     639         _np_qint8,
#     640     types_pb2.DT_QUINT8_REF:
#     641         _np_quint8,
#     642     types_pb2.DT_QINT16_REF:
#     643         _np_qint16,
#     644     types_pb2.DT_QUINT16_REF:
#     645         _np_quint16,
#     646     types_pb2.DT_QINT32_REF:
#     647         _np_qint32,
#     648     types_pb2.DT_BFLOAT16_REF:
#     649         _np_bfloat16,
#     650 }
#     652 _QUANTIZED_DTYPES_NO_REF = frozenset([qint8, quint8, qint16, quint16, qint32])
#     653 _QUANTIZED_DTYPES_REF = frozenset(
#     654     [qint8_ref, quint8_ref, qint16_ref, quint16_ref, qint32_ref])
#
# File ~\anaconda3\envs\tflow\lib\site-packages\numpy\__init__.py:305, in __getattr__(attr)
#     300     warnings.warn(
#     301         f"In the future `np.{attr}` will be defined as the "
#     302         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     304 if attr in __former_attrs__:
# --> 305     raise AttributeError(__former_attrs__[attr])
#     307 # Importing Tester requires importing all of UnitTest which is not a
#     308 # cheap import Since it is mainly used in test suits, we lazy import it
#     309 # here to save on the order of 10 ms of import time for most users
#     310 #
#     311 # The previous way Tester was imported also had a side effect of adding
#     312 # the full `numpy.testing` namespace
#     313 if attr == 'testing':
#
# AttributeError: module 'numpy' has no attribute 'object'.
# `np.object` was a deprecated alias for the builtin `object`. To avoid this error in existing code, use `object` by itself. Doing this will not modify any behavior and is safe.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
